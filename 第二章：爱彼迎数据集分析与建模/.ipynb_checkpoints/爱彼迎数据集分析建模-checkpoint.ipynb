# %% [markdown]
# ### 导入工具包

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 日期与价格

# %%
calendar = pd.read_csv('calendar.csv.gz')
print('We have', calendar.date.nunique(), 'days and', calendar.listing_id.nunique(), 'unique listings in the calendar data.')
# Out:
# We have 366 days and 17653 unique listings in the calendar data.

# %%
calendar.date.min(), calendar.date.max()
# Out:
# ('2017-04-07', '2018-04-07')

# %% [markdown]
# Calendar data covers one year time frame, that is, price and availability every day for the next one year.

# %%
calendar.isnull().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price         3068162
# dtype: int64

# %%
calendar=calendar.dropna()

# %%
calendar.shape
# Out:
# (3375183, 4)

# %%
calendar.head()
# Out:
#      listing_id        date available   price
# 365    14958299  2018-03-25         t  $60.00
# 366    14958299  2018-03-24         t  $60.00
# 367    14958299  2018-03-23         t  $60.00
# 368    14958299  2018-03-22         t  $60.00
# 369    14958299  2018-03-21         t  $60.00

# %% [markdown]
# ### 不同月份价格

# %% [markdown]
# Remove "$" symbol in price column and convert it to numeric, and convert date to datetime data type.

# %%
calendar['date'] = pd.to_datetime(calendar['date'])
calendar.head()
# Out:
#      listing_id       date available   price
# 365    14958299 2018-03-25         t  $60.00
# 366    14958299 2018-03-24         t  $60.00
# 367    14958299 2018-03-23         t  $60.00
# 368    14958299 2018-03-22         t  $60.00
# 369    14958299 2018-03-21         t  $60.00

# %%
calendar['price'] = calendar['price'].str.replace('$', '')
calendar.head()
# Out:
#      listing_id       date available  price
# 365    14958299 2018-03-25         t  60.00
# 366    14958299 2018-03-24         t  60.00
# 367    14958299 2018-03-23         t  60.00
# 368    14958299 2018-03-22         t  60.00
# 369    14958299 2018-03-21         t  60.00

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3375183 entries, 365 to 6443343
# Data columns (total 4 columns):
# listing_id    int64
# date          datetime64[ns]
# available     object
# price         object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 128.8+ MB

# %%
calendar['price'] = calendar['price'].str.replace(',', '')
calendar['price'] = calendar['price'].astype(float)
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3375183 entries, 365 to 6443343
# Data columns (total 4 columns):
# listing_id    int64
# date          datetime64[ns]
# available     object
# price         float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 128.8+ MB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
calendar['date'].dt.strftime('%B')
# Out:
# 365           March
# 366           March
# 367           March
# 368           March
# 369           March
# 370           March
# 371           March
# 372           March
# 373           March
# 374           March
# 375           March
# 376           March
# 377           March
# 378           March
# 379           March
# 380           March
# 381           March
# 382           March
# 383           March
# 384           March
# 385           March
# 386           March
# 387           March
# 388           March
# 389           March
# 390        February
# 391        February
# 392        February
# 393        February
# 394        February
#              ...
# 6443226        June
# 6443227        June
# 6443250         May
# 6443251         May
# 6443252         May
# 6443253         May
# 6443254         May
# 6443255         May
# 6443256         May
# 6443257         May
# 6443258         May
# 6443259         May
# 6443260         May
# 6443266         May
# 6443269         May
# 6443270         May
# 6443271         May
# 6443272         May
# 6443273         May
# 6443274         May
# 6443281       April
# 6443282       April
# 6443283       April
# 6443284       April
# 6443285       April
# 6443286       April
# 6443336       April
# 6443341       April
# 6443342       April
# 6443343       April
# Name: date, Length: 3375183, dtype: object

# %%
mean_of_month = calendar.groupby(calendar['date'].dt.strftime('%B'),
                                 sort=False)['price'].mean()

# %%
calendar['price'] = calendar['price'].str.replace(',', '')
calendar['price'] = calendar['price'].str.replace('$', '')
calendar['price'] = calendar['price'].astype(float)
calendar['date'] = pd.to_datetime(calendar['date'])
mean_of_month = calendar.groupby(calendar['date'].dt.strftime('%B'),
                                 sort=False)['price'].mean()
mean_of_month.plot(kind = 'barh' , figsize = (12,7))
plt.xlabel('average monthly price');

# %% [markdown]
# The Airbnb price in Toronto increases in the months of July, August and October. Agreed, these three months are the best months visiting Toronto.

# %% [markdown]
# How price changes during day of week?

# %%
calendar['dayofweek'] = calendar.date.dt.weekday_name
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
price_week=calendar[['dayofweek','price']]
price_week = calendar.groupby(['dayofweek']).mean().reindex(cats)
price_week.drop('listing_id', axis=1, inplace=True)
price_week.plot()
ticks = list(range(0, 7, 1)) # points on the x axis where you want the label to appear
labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
plt.xticks(ticks, labels);

# %% [markdown]
# Fridays and Saturdays are over $10 more expensive than the rest of the week.

# %% [markdown]
# ### Listings
#
# #### Number of listings in each neighbourhood

# %%
listings = pd.read_csv('listings.csv.gz')
print('We have', listings.id.nunique(), 'listings in the listing data.')
# Out:
# We have 17653 listings in the listing data.
# e:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0   8207551   https://www.airbnb.com/rooms/8207551  20170407214050
# 1  14958299  https://www.airbnb.com/rooms/14958299  20170407214050
# 2   7766152   https://www.airbnb.com/rooms/7766152  20170407214050
# 3   9237132   https://www.airbnb.com/rooms/9237132  20170407214050
# 4   1406827   https://www.airbnb.com/rooms/1406827  20170407214050
#
#   last_scraped                                 name  \
# 0   2017-04-08    Room in Sant Antoni huge terrasse
# 1   2017-04-08    Next To Las Ramblas, Unique, Wif1
# 2   2017-04-08    Sunny whole flat in Raval/Ramblas
# 3   2017-04-08  Apartment in the heart of Barcelona
# 4   2017-04-08  Centric Bohemian next Ramblas&Macba
#
#                                              summary  \
# 0  Located between Sant Antoni & Universitat (met...
# 1  Brand new apartment, cosy and clean.  Only 5 m...
# 2  Calm, sunny 43sqm flat. Living room w/balcony ...
# 3  The apartment is an ideal place for relax afte...
# 4  Artistic cosy renovated flat 40m2 with balcony...
#
#                                                space  \
# 0  the apartment is located on the 7th floor and ...
# 1  Fun, bohemian. Real Catalan style Well equippe...
# 2  Very luminous and calm, in a neighborhood than...
# 3  Both rooms include a comfortable double bed wi...
# 4  The apartment is 40m2 and has everything you n...
#
#                                          description experiences_offered  \
# 0  Located between Sant Antoni & Universitat (met...                none
# 1  Brand new apartment, cosy and clean.  Only 5 m...                none
# 2  Calm, sunny 43sqm flat. Living room w/balcony ...                none
# 3  The apartment is an ideal place for relax afte...                none
# 4  Artistic cosy renovated flat 40m2 with balcony...                none
#
#                                neighborhood_overview        ...          \
# 0  Sant Antoni is a very central neighborhood and...        ...
# 1                                                NaN        ...
# 2  Very central, lively, popular hood. Near the s...        ...
# 3                                                NaN        ...
# 4  Raval is the distric where most of the young a...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                1     NaN                NaN
# 1                 8.0                1     NaN                NaN
# 2                 9.0                1     NaN                NaN
# 3                 9.0                1     NaN                NaN
# 4                 8.0                1   43212                NaN
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                0              strict                             0
# 1                1              strict                             0
# 2                0              strict                             0
# 3                1            flexible                             0
# 4                1            moderate                             0
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                0                              2
# 1                                0                              1
# 2                                0                              1
# 3                                0                              1
# 4                                0                              1
#
#    reviews_per_month
# 0               0.11
# 1               2.26
# 2               0.40
# 3               3.17
# 4               5.06
#
# [5 rows x 95 columns]

# %%
listings.groupby(by='neighbourhood_cleansed').count()[['id']].sort_values(by='id', ascending=False).head(10)
# Out:
#                                          id
# neighbourhood_cleansed
# la Dreta de l'Eixample                 1641
# el Raval                               1407
# el Barri Gòtic                         1161
# la Vila de Gràcia                      1152
# Sant Pere, Santa Caterina i la Ribera  1058
# el Poble Sec                            989
# l'Antiga Esquerra de l'Eixample         961
# la Sagrada Família                      943
# Sant Antoni                             920
# la Nova Esquerra de l'Eixample          759

# %% [markdown]
# The neighbourhood that has the highest number of listings is Waterfront Communities-The Island, and almost four times more than the second most neighbourhood (Niagara). From map at Inside Airbnb, we can see that too.

# %% [markdown]
# ### review score rating

# %%
plt.figure(figsize=(12,6))
sns.distplot(listings.review_scores_rating.dropna(), rug=True)
sns.despine()
plt.show();

# %%
listings.review_scores_rating.describe()
# Out:
# count    14015.000000
# mean        89.937139
# std          9.374362
# min         20.000000
# 25%         86.000000
# 50%         92.000000
# 75%         96.000000
# max        100.000000
# Name: review_scores_rating, dtype: float64

# %% [markdown]
# As expected, most of reviewers leave high scores.

# %% [markdown]
# ### Exploring the price

# %%
listings['price'] = listings['price'].str.replace(',', '')
listings['price'] = listings['price'].str.replace('$', '')
listings['price'] = listings['price'].astype(float)

listings['price'].describe()
# Out:
# count    17653.000000
# mean        92.092392
# std        159.911422
# min          9.000000
# 25%         35.000000
# 50%         62.000000
# 75%        105.000000
# max       9379.000000
# Name: price, dtype: float64

# %%
high_price = listings.sort_values("price", ascending=False)
high_price.head(10)
# Out:
#              id                            listing_url       scrape_id  \
# 3506   17726001  https://www.airbnb.com/rooms/17726001  20170407214050
# 7835   13835559  https://www.airbnb.com/rooms/13835559  20170407214050
# 2551   10115876  https://www.airbnb.com/rooms/10115876  20170407214050
# 5025   17836417  https://www.airbnb.com/rooms/17836417  20170407214050
# 13004  10715472  https://www.airbnb.com/rooms/10715472  20170407214050
# 9099    4970202   https://www.airbnb.com/rooms/4970202  20170407214050
# 5099   17633461  https://www.airbnb.com/rooms/17633461  20170407214050
# 13999   9537761   https://www.airbnb.com/rooms/9537761  20170407214050
# 3561   17725108  https://www.airbnb.com/rooms/17725108  20170407214050
# 10485  17729590  https://www.airbnb.com/rooms/17729590  20170407214050
#
#       last_scraped                                            name  \
# 3506    2017-04-08  2427 - AB Plaza Catalunya Luxury Apartment 3-4
# 7835    2017-04-08                   Habitación en sagrada familia
# 2551    2017-04-08                   Apartamento en Barcelona [ 3]
# 5025    2017-04-08              Ref2298 Arago Executive Suites 4-C
# 13004   2017-04-08                 Stunning 3 bed duplex penthouse
# 9099    2017-04-08              Perfect apartment  BCN city center
# 5099    2017-04-08            Ref2280 AB Roma Executive Suites 1-A
# 13999   2017-04-08                 Apartment in the city center B1
# 3561    2017-04-08  2425 - AB Plaza Catalunya Luxury Apartment 3-1
# 10485   2017-04-08     1918 Paral.lel Spacious Apartment 3rd Floor
#
#                                                  summary  \
# 3506   This luxurious, two bedroom apartment is perfe...
# 7835   Barrio tranquilo bien comunicado a 10 min del ...
# 2551   Hello, our apartments are located in central B...
# 5025   This chic and stylish apartment, in a recently...
# 13004  Spacious 3 bedroom penthouse with 2 fantastic ...
# 9099   Beautiful apartment in the city center, with t...
# 5099   Centrally located apartment in the Eixample ne...
# 13999  The apartment is located in the city center -n...
# 3561   This luxurious two-bedroom apartment in Barcel...
# 10485  This is a wonderful apartment is located in th...
#
#                                                    space  \
# 3506   With Plaça Catalunya and Passeig de Gràcia at ...
# 7835                                                 NaN
# 2551   El barrio The Gothic Quarter (in Catalan: Barr...
# 5025   This luminous, air-conditioned apartment has 2...
# 13004  This attractive very well equipped flat accomm...
# 9099   Amazing apartment in the center of the city, w...
# 5099   This apartment is perfect for the whole family...
# 13999  The apartment is fully equipped and can accomm...
# 3561   By choosing this apartment, visitors will find...
# 10485  The apartment itself is large with plenty of s...
#
#                                              description experiences_offered  \
# 3506   This luxurious, two bedroom apartment is perfe...                none
# 7835   Barrio tranquilo bien comunicado a 10 min del ...                none
# 2551   Hello, our apartments are located in central B...                none
# 5025   This chic and stylish apartment, in a recently...                none
# 13004  This attractive very well equipped flat accomm...                none
# 9099   Beautiful apartment in the city center, with t...                none
# 5099   Centrally located apartment in the Eixample ne...                none
# 13999  The apartment is located in the city center -n...                none
# 3561   This luxurious two-bedroom apartment in Barcel...                none
# 10485  This is a wonderful apartment is located in th...                none
#
#                                    neighborhood_overview        ...          \
# 3506                                                 NaN        ...
# 7835                                                 NaN        ...
# 2551                                                 NaN        ...
# 5025   Eixample is Catalan for ´extension´, meaning a...        ...
# 13004  Whether you are visiting for business or pleas...        ...
# 9099   The neighbourhood is full of shops, trendy pla...        ...
# 5099   It is a central neighborhood with a variety of...        ...
# 13999  This luxury apartment is located in the best a...        ...
# 3561                                                 NaN        ...
# 10485                                                NaN        ...
#
#       review_scores_value requires_license                          license  \
# 3506                  8.0                1                      HUTB-007871
# 7835                  9.0                1                              NaN
# 2551                  9.0                1                              NaN
# 5025                  NaN                1  Número de licencia: HUTB-003733
# 13004                 NaN                1                              NaN
# 9099                 10.0                1                              NaN
# 5099                  NaN                1      Licence number: HUTB-002010
# 13999                 8.0                1                       HUTB013010
# 3561                 10.0                1                       HUTB-00226
# 10485                10.0                1      Licence number: HUTB-009308
#
#       jurisdiction_names instant_bookable cancellation_policy  \
# 3506                 NaN                1              strict
# 7835                 NaN                0              strict
# 2551                 NaN                1              strict
# 5025                 NaN                1              strict
# 13004                NaN                0              strict
# 9099                 NaN                0              strict
# 5099                 NaN                1              strict
# 13999                NaN                1              strict
# 3561                 NaN                1              strict
# 10485                NaN                1              strict
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 3506                              0                                0
# 7835                              0                                0
# 2551                              0                                0
# 5025                              0                                0
# 13004                             0                                0
# 9099                              0                                0
# 5099                              0                                0
# 13999                             0                                0
# 3561                              0                                0
# 10485                             0                                0
#
#       calculated_host_listings_count  reviews_per_month
# 3506                              49               1.00
# 7835                               1               1.45
# 2551                              10               1.91
# 5025                              49                NaN
# 13004                              1                NaN
# 9099                               1               0.08
# 5099                              49                NaN
# 13999                             17               0.09
# 3561                              49               1.00
# 10485                             49               1.00
#
# [10 rows x 95 columns]

# %% [markdown]
# I decided to remove listings that exceed $600/night, as well as 7 listings at price 0, for the following exploratory analysis.

# %%
listings.loc[listings['price'] > 600]['price'].describe()
# Out:
# count      88.000000
# mean     1374.988636
# std      1526.680980
# min       650.000000
# 25%       750.000000
# 50%       992.500000
# 75%      1125.000000
# max      9379.000000
# Name: price, dtype: float64

# %%
listings.loc[listings['price'] == 0]['price'].count()
# Out:
# 0

# %% [markdown]
# #### Listings price distribution after removing outliers

# %%
listings.loc[(listings.price <= 600) & (listings.price > 0)].price.hist(bins=200)
plt.ylabel('Count')
plt.xlabel('Listing price in $')
plt.title('Histogram of listing prices');

# %% [markdown]
# #### 物业类型

# %%
#f, ax= plt.subplots(figsize = (14, 10))
sort_price = listings.loc[(listings.price <= 600) & (listings.price > 0)]\
                    .groupby('property_type')['price']\
                    .median()\
                    .sort_values(ascending=False)\
                    .index
sns.boxplot(y='price', x='property_type', data=listings.loc[(listings.price <= 600) & (listings.price > 0)], order=sort_price)
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show();

# %% [markdown]
# When we look at the median price for each property type, we have to be careful that we can't say "The most expensive property type is Aparthotel, and that Tent and Parking Space have a higher median price than Apartment and Castle.", because Aparthotel, tend and parking space has only one listing each.

# %% [markdown]
# #### room type vs. price

# %%
f, ax= plt.subplots(figsize = (14, 10))
sort_price = listings.loc[(listings.price <= 600) & (listings.price > 0)]\
                    .groupby('room_type')['price']\
                    .median()\
                    .sort_values(ascending=False)\
                    .index
sns.boxplot(y='price', x='room_type', data=listings.loc[(listings.price <= 600) & (listings.price > 0)], order=sort_price)
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show();

# %% [markdown]
# This goes without saying, entire room/apt has a a much higher median price than the other room types.

# %%
listings.loc[(listings.price <= 600) & (listings.price > 0)].pivot(columns = 'room_type', values = 'price').plot.hist(stacked = True, bins=100)
plt.xlabel('Listing price in $');

# %% [markdown]
# Entire home/apt also has the most number of listings. Inside Airbnb has indicated that Entire homes or apartments highly available year-round for tourists, probably don't have the owner present, could be illegal, and more importantly, are displacing residents. We will put our worries away for the moment.

# %% [markdown]
# #### bed type vs. price

# %%
sort_price = listings.loc[(listings.price <= 600) & (listings.price > 0)]\
                    .groupby('bed_type')['price']\
                    .median()\
                    .sort_values(ascending=False)\
                    .index
sns.boxplot(y='price', x='bed_type', data=listings.loc[(listings.price <= 600) & (listings.price > 0)], order=sort_price)
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show();

# %% [markdown]
# There is no surprise.

# %% [markdown]
# #### 设施
#
# The amenities text field needs some cleaning.

# %%
listings.amenities = listings.amenities.str.replace("[{}]", "").str.replace('"', "")

# %%
listings['amenities'].head()
# Out:
# 0    TV,Internet,Wireless Internet,Air conditioning...
# 1    Internet,Wireless Internet,Kitchen,Washer,Esse...
# 2    Internet,Wireless Internet,Air conditioning,Ki...
# 3    Internet,Wireless Internet,Kitchen,Elevator in...
# 4    Wireless Internet,Kitchen,Smoking allowed,Pets...
# Name: amenities, dtype: object

# %% [markdown]
# #### Top 20 most common amenities

# %%
f, ax= plt.subplots(figsize = (14, 10))
pd.Series(np.concatenate(listings['amenities'].map(lambda amns: amns.split(","))))\
    .value_counts().head(20)\
    .plot(kind='bar')
ax = plt.gca()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)
plt.show();

# %% [markdown]
# Interesting, amenities feature does seem to have some relationship with price.

# %% [markdown]
# Vast majority of the listings have one bed, the one-bed listing prices have a very wide range. There are listings that have no bed.

# %%
f, ax= plt.subplots(figsize = (14, 10))
sns.boxplot(y='price', x='beds', data = listings.loc[(listings.price <= 600) & (listings.price > 0)])
plt.show();

# %% [markdown]
# Interesting to discover that the median price for no bed listings is higher than 1-bed and 2-bed listings, and median price for 10-bed listings is very low.

# %% [markdown]
# #### numeric features
#
# We select several numeric features and try to explore them all together.

# %%
col = ['host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'number_of_reviews', 'review_scores_rating', 'reviews_per_month']
sns.set(style="ticks", color_codes=True)
sns.pairplot(listings.loc[(listings.price <= 600) & (listings.price > 0)][col].dropna())
plt.show();

# %%
corr = listings.loc[(listings.price <= 600) & (listings.price > 0)][col].dropna().corr()
plt.figure(figsize = (6,6))
sns.set(font_scale=1)
sns.heatmap(corr, cbar = True, annot=True, square = True, fmt = '.2f', xticklabels=col, yticklabels=col)
plt.show();

# %% [markdown]
# There are some not bad news such as number of bedrooms and accommodates seem to be correlated with price.

# %%
f, ax= plt.subplots(figsize = (14, 10))
sns.heatmap(listings.loc[(listings.price <= 600) & (listings.price > 0)]\
                .groupby(['bathrooms', 'bedrooms'])\
                .count()['price']\
                .reset_index()\
                .pivot('bathrooms', 'bedrooms', 'price')\
                .sort_index(ascending=False),
            cmap="Oranges", fmt='.0f', annot=True, linewidths=0.5)
plt.show();

# %% [markdown]
# Vast majority of listings have one bedroom and 1 bathroom.

# %%
f, ax= plt.subplots(figsize = (14, 10))
sns.heatmap(listings.loc[(listings.price <= 600) & (listings.price > 0)]\
                .groupby(['bathrooms', 'bedrooms'])\
                .mean()['price']\
                .reset_index()\
                .pivot('bathrooms', 'bedrooms', 'price')\
                .sort_index(ascending=False),
            cmap="Oranges", fmt='.0f', annot=True, linewidths=0.5)
plt.show()

# %% [markdown]
# It looks like listings with 6 bedrooms and 4 bathrooms have the highest median price. But we must be skeptical about this finding because from the above single graph, we don't know how many listings in this category.

# %% [markdown]
# ## Modeling Lising Prices

# %% [markdown]
# ### Data preprocessing and feature engineering

# %%
listings = pd.read_csv('listings.csv.gz')
# Out:
# e:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Processing price feature. The feature we are going to model and predict.

# %%
listings['price'] = listings['price'].str.replace(',', '')
listings['price'] = listings['price'].str.replace('$', '')
listings['price'] = listings['price'].astype(float)
listings = listings.loc[(listings.price <= 600) & (listings.price > 0)]

# %% [markdown]
# Term document matrix for amenities feature.

# %%
listings.amenities = listings.amenities.str.replace("[{}]", "").str.replace('"', "")

# %%
listings.amenities.head()
# Out:
# 0    TV,Internet,Wireless Internet,Air conditioning...
# 1    Internet,Wireless Internet,Kitchen,Washer,Esse...
# 2    Internet,Wireless Internet,Air conditioning,Ki...
# 3    Internet,Wireless Internet,Kitchen,Elevator in...
# 4    Wireless Internet,Kitchen,Smoking allowed,Pets...
# Name: amenities, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer =  CountVectorizer(tokenizer=lambda x: x.split(','))
amenities = count_vectorizer.fit_transform(listings['amenities'])
df_amenities = pd.DataFrame(amenities.toarray(), columns=count_vectorizer.get_feature_names())
df_amenities = df_amenities.drop('',1)

# %% [markdown]
# Replace the values in the following feature to 0 if "f", to 1 if "t".

# %%
columns =  ['host_is_superhost', 'host_identity_verified', 'host_has_profile_pic',
                   'is_location_exact', 'requires_license', 'instant_bookable',
                   'require_guest_profile_picture', 'require_guest_phone_verification']
for c in columns:
    listings[c] = listings[c].replace('f',0,regex=True)
    listings[c] = listings[c].replace('t',1,regex=True)

# %% [markdown]
# Same way to clean up the other money value columns.

# %%
listings['security_deposit'] = listings['security_deposit'].fillna(value=0)
listings['security_deposit'] = listings['security_deposit'].replace( '[\$,)]','', regex=True ).astype(float)
listings['cleaning_fee'] = listings['cleaning_fee'].fillna(value=0)
listings['cleaning_fee'] = listings['cleaning_fee'].replace( '[\$,)]','', regex=True ).astype(float)

# %% [markdown]
# The following are the numeric features we will be using.

# %%
listings_new = listings[['host_is_superhost', 'host_identity_verified', 'host_has_profile_pic','is_location_exact', 
                         'requires_license', 'instant_bookable', 'require_guest_profile_picture', 
                         'require_guest_phone_verification', 'security_deposit', 'cleaning_fee', 
                         'host_listings_count', 'host_total_listings_count', 'minimum_nights',
                     'bathrooms', 'bedrooms', 'guests_included', 'number_of_reviews','review_scores_rating', 'price']]

# %% [markdown]
# Fill the missing values in the numeric features with median.

# %%
for col in listings_new.columns[listings_new.isnull().any()]:
    print(col)
# Out:
# host_is_superhost
# host_identity_verified
# host_has_profile_pic
# host_listings_count
# host_total_listings_count
# bathrooms
# bedrooms
# review_scores_rating

# %%
for col in listings_new.columns[listings_new.isnull().any()]:
    listings_new[col] = listings_new[col].fillna(listings_new[col].median())
# Out:
# e:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Processing Categorical features

# %%
for cat_feature in ['zipcode', 'property_type', 'room_type', 'cancellation_policy', 'neighbourhood_cleansed', 'bed_type']:
    listings_new = pd.concat([listings_new, pd.get_dummies(listings[cat_feature])], axis=1)

# %% [markdown]
# Adding amenities feature

# %%
listings_new = pd.concat([listings_new, df_amenities], axis=1, join='inner')

# %% [markdown]
# Data preprocessing and feature engineering done!

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

y = listings_new['price']
x = listings_new.drop('price', axis =1)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)
rf = RandomForestRegressor(n_estimators=500, 
                               criterion='mse', 
                               random_state=3, 
                               n_jobs=-1)
rf.fit(X_train, y_train)
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 49.143
# R^2 test: 0.596

# %% [markdown]
# ### LightGBM

# %%
from lightgbm import LGBMRegressor

y = listings_new['price']
x = listings_new.drop('price', axis =1)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)
fit_params={
    "early_stopping_rounds":20, 
            "eval_metric" : 'rmse', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'feature_name': 'auto', 
            'categorical_feature': 'auto'
           }

# %%
lgb = LGBMRegressor(num_leaves= 25, max_depth=20, 
                         random_state=0, 
                         silent=True, 
                         metric='rmse', 
                         n_jobs=4, 
                         n_estimators=1000,
                         colsample_bytree=0.9,
                         subsample=0.9,
                         learning_rate=0.01)
lgb.fit(X_train.values, y_train.values, **fit_params)
# Out:
# Training until validation scores don't improve for 20 rounds.
# [100]	valid's rmse: 56.791
# [200]	valid's rmse: 51.9721
# [300]	valid's rmse: 50.1772
# [400]	valid's rmse: 49.2827
# [500]	valid's rmse: 48.7304
# [600]	valid's rmse: 48.4033
# [700]	valid's rmse: 48.1814
# [800]	valid's rmse: 48.0441
# [900]	valid's rmse: 47.9161
# [1000]	valid's rmse: 47.8274
# Did not meet early stopping. Best iteration is:
# [1000]	valid's rmse: 47.8274
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=0.9,
#        learning_rate=0.01, max_depth=20, metric='rmse',
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=1000, n_jobs=4, num_leaves=25, objective=None,
#        random_state=0, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#        subsample=0.9, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = clf.predict(X_test.values)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# R^2 test: 0.618
